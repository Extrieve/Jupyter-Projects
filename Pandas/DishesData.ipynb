# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('RAW_recipes.csv')
test["name"].fillna("missing")
test = df.loc[df['name'].notnull()]

# %%
test = df.loc[df['name'].notnull()]
test = test
test
# Out:
#                                                 name      id  minutes  \
# 0         arriba   baked winter squash mexican style  137739       55
# 1                   a bit different  breakfast pizza   31490       30
# 2                          all in the kitchen  chili  112140      130
# 3                                 alouette  potatoes   59389       45
# 4                 amish  tomato ketchup  for canning   44061      190
# ...                                              ...     ...      ...
# 231632                                   zydeco soup  486161       60
# 231633                              zydeco spice mix  493372        5
# 231634                     zydeco ya ya deviled eggs  308080       40
# 231635        cookies by design   cookies on a stick  298512       29
# 231636  cookies by design   sugar shortbread cookies  298509       20
#
#         contributor_id   submitted  \
# 0                47892  2005-09-16
# 1                26278  2002-06-17
# ...

# %%
cuisines = ['French', 'Japanese', 'Seafood', 'Chinese', 'Asian', 'European', 'Filipino', 'American', 
            'Korean', 'Cafe', 'Italian', 'FastFood', 'Bakery', 'Brazilian', 'Pizza', 'Arabian', 'BarFood', 'Mexican', 
            'International', 'Peruvian', 'Desserts', 'Juices', 'Beverages', 'Lebanese', 'Burger', 'Steak', 'Indian', 
            'Sushi', 'BBQ']

# %%
for item in cuisines:
    print(item)
# Out:
# French
# Japanese
# Seafood
# Chinese
# Asian
# European
# Filipino
# American
# Korean
# Cafe
# Italian
# FastFood
# Bakery
# Brazilian
# Pizza
# Arabian
# BarFood
# Mexican
# International
# Peruvian
# Desserts
# Juices
# Beverages
# Lebanese
# Burger
# Steak
# Indian
# Sushi
# BBQ

# %%
for cuisine in cuisines:
    cuisine = cuisine.lower()
    data = test.loc[test['name'].str.contains(f'{cuisine}')]
    data = data['name'].to_frame()
    file = f'cuisine_data/{cuisine}_dishes.csv'
    data.to_csv(file, index=False)

# %%
cuisine = 'japanese'.lower()
data = test.loc[test['name'].str.contains(f'{cuisine}')]
data
# Out:
#                                                  name      id  minutes  \
# 817             10 min japanese simmered tofu hot pot   39169       10
# 4358                 amakara japanese ginger dressing  178115        5
# 9297    asian honey chiffon cake  japanese  taiwanese  365841       60
# 9832          asparagus negimaki  japanese beef rolls  364570       15
# 10786                        authentic japanese gyoza  254919       40
# ...                                               ...     ...      ...
# 228948      yakisoba  japanese spaghetti  5 ww points  351626       35
# 228949             yakisoba  japanese style chow mein  112534       20
# 228956    yakitori   japanese grilled chicken skewers  302806       30
# 228959            yakitori  skewered japanese chicken  501714       35
# 230302           zaru soba   chilled japanese noodles  448296       10
#
#         contributor_id   submitted  \
# 817              54102  2002-09-03
# 4358            197496  2006-07-17
# ...
