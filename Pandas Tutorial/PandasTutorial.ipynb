# %% [markdown]
# # Pandas Tutorial

# %%
import pandas as pd
df = pd.read_csv('modified_pokemon.csv')

# Loading excel, and txt formats.
# df_xlsx = pd.read_excel('pokemon_data.xlsx')

# Loading a tab separated file.
# df = pd.read_csv("poemon_data.txt", delimiter='\t')

df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# # Reading Data in Pandas

# %%
### Read Headers
#print(df.columns)

### Read Each Column

## Getting specific attributes
#print(df[['Name', 'Type 1', 'HP']].head())


### Read Each Row

## Getting a specific row
#print(df.iloc[0:10])

## Iterating through every row as your going through your dataset
#for index, row in df.iterrows():
#    print(index, row['Name'])

# Access the rows that only have this specific element.
df.loc[df['Type 1'] == "Grass"]

### Read a specific location (row, col)
## Using iloc to get a specific attribute based on row and col
#print("\n", df.iloc[1, 4])
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 48        75       65     30           1      False
# ..       ...      ...    ...         ...        ...
# 718       48       45     38           6      False
# 719       56       58     57           6      False
# 720       74       75     64           6      False
# 740       62       57     52           6      False
# 741       97       81     68           6      False
#
# [70 rows x 12 columns]

# %% [markdown]
# # Sorting/Describing Data

# %%
## Gives us all the general statistical data: mean, std. dev, amongst others...
#df.describe()

#How to sort based on a condition
df.sort_values(['Type 1', 'HP'], ascending=[True, False])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520      116       56     95           4      False
# 698      135      105    100           5      False
# 231       40       95     85           2      False
# 232       40      105     75           2      False
# 678      100       60    145           5      False
# ..       ...      ...    ...         ...        ...
# 106       25       25     50           1      False
# 125       70       25     60           1      False
# 129       70       55     85           1      False
# 139       15       20     80           1      False
# 381       10       55     80           3      False
#
# [800 rows x 12 columns]

# %% [markdown]
# # Making changes to data

# %%
## Making a total category
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed'] 
# The end parameter is non-inclusive
df['Total'] = df.iloc[:, 4:10].sum(axis=1)

# Move the new column
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

# Remove a column
#df = df.drop(columns=['Total'])

# Sorting through the new parameter.
df.sort_values('Total', ascending=False)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# ..   ...                    ...      ...       ...    ...  ...     ...
# 13    10               Caterpie      Bug       NaN    195   45      30
# 288  265                Wurmple      Bug       NaN    195   45      45
# 446  401              Kricketot      Bug       NaN    194   37      25
# 322  298                Azurill   Normal     Fairy    190   50      20
# 206  191                Sunkern    Grass       NaN    180   30      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 426      100      180      100    115           3       True
# 164       70      194      120    140           1       True
# 163      100      154      100    130           1       True
# 422       90      180      160     90           3       True
# 424      160      150       90     90           3       True
# ..       ...      ...      ...    ...         ...        ...
# 13        35       20       20     45           1      False
# 288       35       20       30     20           3      False
# 446       41       25       41     25           4      False
# 322       40       20       40     20           3      False
# 206       30       30       30     30           2      False
#
# [800 rows x 13 columns]

# %% [markdown]
# # Saving our Data (Exporting into Desired Format)

# %%
## Save our file, the second argument makes it so that there is not indexes
df.to_csv('modified_pokemon.csv', index=False)
df.to_excel('modified_pokemons.xlsx', index=False)
df.to_csv('modified.csv', index=False, sep='\t')

# %% [markdown]
# # Filtering Data

# %%
## Filtering data with 2 specific conditions. Notice how the & operator is not the typical python 'and'
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

## Filtering out a specific string inside the data. THIS SPECIAL CHARACTER IS THE NOT OPERATOR
df_no_mega = df.loc[~df['Name'].str.contains('Mega')]

new_df = new_df.reset_index()
df_no_mega

## Save the filtered data as a new CSV
#new_df.to_csv('filtered_grass_poison.csv')
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 4         60       50     65           1      False
# 5         80       65     80           1      False
# ..       ...      ...    ...         ...        ...
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [751 rows x 13 columns]

# %%
import re
## Finding out if type 1 is equal to fire or grass. flags key allows to ignore case in this instance.
#df.loc[df['Type 1'].str.contains('Fire|Grass', flags=re.I, regex=True)]

## This expression allows us to find pokemon which names start with 'pi'
df.loc[df['Name'].str.contains('^pi[a:z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# 578  519               Pidove    Normal    Flying    264   50      55
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20        40       35       35     56           1      False
# 21        55       50       50     71           1      False
# 22        75       70       70    101           1      False
# 23        80      135       80    121           1      False
# 30        40       50       50     90           1      False
# 136      100       55       70     85           1      False
# 137      120       65       90    105           1      False
# 186       15       35       35     60           2      False
# 219       90       35       35     15           2      False
# 239       80       60       60     50           2      False
# 438       53       61       56     40           4      False
# 558       55       70       55     55           5      False
# 578       50       36       30     43           5      False

# %% [markdown]
# # Conditional Changes

# %%
## Change the name of a specific attribute. In this case, fire -> flamer
#df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

## Reverting the change.
#df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

## Making all the fire type pokemons legendary
#df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True

# Modify multiple paramters based on specified conditions.
#df.loc[df['Total'] >= 600, ['Generation', 'Legendary']] = ['Test 1', 'Test 2']
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# # Aggregate Statistics (Groupby)

# %%
## Use a hoolistic approach of grouping our dataset.
## Get the mean of all metrics by type 1
#df.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)

## It doesn't make any sense to get a sum of all these values
#df.groupby(['Type 1']).sum()

## Get a count according to an attribute.
df['Count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %% [markdown]
# # Working with large amounts of Data

# %%
## Imagine working with a file that's multiple gigs large. In these cases we have to partition the file
## Reading an n number of rows at a time.
for df in pd.read_csv('modified.csv', chunksize=5):
    print(df)
# Out:
#   #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t318\t45\t49\t49\t...
# 1  2\tIvysaur\tGrass\tPoison\t405\t60\t62\t63\t80...
# 2  3\tVenusaur\tGrass\tPoison\t525\t80\t82\t83\t1...
# 3  3\tVenusaurMega Venusaur\tGrass\tPoison\t625\t...
# 4  4\tCharmander\tFire\t\t309\t39\t52\t43\t60\t50...
#   #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 5  5\tCharmeleon\tFire\t\t405\t58\t64\t58\t80\t65...
# 6  6\tCharizard\tFire\tFlying\t534\t78\t84\t78\t1...
# 7  6\tCharizardMega Charizard X\tFire\tDragon\t63...
# 8  6\tCharizardMega Charizard Y\tFire\tFlying\t63...
# 9  7\tSquirtle\tWater\t\t314\t44\t48\t65\t50\t64\...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 10  8\tWartortle\tWater\t\t405\t59\t63\t80\t65\t80...
# 11  9\tBlastoise\tWater\t\t530\t79\t83\t100\t85\t1...
# 12  9\tBlastoiseMega Blastoise\tWater\t\t630\t79\t...
# 13  10\tCaterpie\tBug\t\t195\t45\t30\t35\t20\t20\t...
# 14  11\tMetapod\tBug\t\t205\t50\t20\t55\t25\t25\t3...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 15  12\tButterfree\tBug\tFlying\t395\t60\t45\t50\t...
# 16  13\tWeedle\tBug\tPoison\t195\t40\t35\t30\t20\t...
# 17  14\tKakuna\tBug\tPoison\t205\t45\t25\t50\t25\t...
# 18  15\tBeedrill\tBug\tPoison\t395\t65\t90\t40\t45...
# 19  15\tBeedrillMega Beedrill\tBug\tPoison\t495\t6...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 20  16\tPidgey\tNormal\tFlying\t251\t40\t45\t40\t3...
# 21  17\tPidgeotto\tNormal\tFlying\t349\t63\t60\t55...
# 22  18\tPidgeot\tNormal\tFlying\t479\t83\t80\t75\t...
# 23  18\tPidgeotMega Pidgeot\tNormal\tFlying\t579\t...
# 24  19\tRattata\tNormal\t\t253\t30\t56\t35\t25\t35...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 25  20\tRaticate\tNormal\t\t413\t55\t81\t60\t50\t7...
# 26  21\tSpearow\tNormal\tFlying\t262\t40\t60\t30\t...
# 27  22\tFearow\tNormal\tFlying\t442\t65\t90\t65\t6...
# 28  23\tEkans\tPoison\t\t288\t35\t60\t44\t40\t54\t...
# 29  24\tArbok\tPoison\t\t438\t60\t85\t69\t65\t79\t...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 30  25\tPikachu\tElectric\t\t320\t35\t55\t40\t50\t...
# 31  26\tRaichu\tElectric\t\t485\t60\t90\t55\t90\t8...
# 32  27\tSandshrew\tGround\t\t300\t50\t75\t85\t20\t...
# 33  28\tSandslash\tGround\t\t450\t75\t100\t110\t45...
# 34  29\tNidoran (Female)\tPoison\t\t275\t55\t47\t5...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 35  30\tNidorina\tPoison\t\t365\t70\t62\t67\t55\t5...
# 36  31\tNidoqueen\tPoison\tGround\t505\t90\t92\t87...
# 37  32\tNidoran (Male)\tPoison\t\t273\t46\t57\t40\...
# 38  33\tNidorino\tPoison\t\t365\t61\t72\t57\t55\t5...
# 39  34\tNidoking\tPoison\tGround\t505\t81\t102\t77...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 40  35\tClefairy\tFairy\t\t323\t70\t45\t48\t60\t65...
# 41  36\tClefable\tFairy\t\t483\t95\t70\t73\t95\t90...
# 42  37\tVulpix\tFire\t\t299\t38\t41\t40\t50\t65\t6...
# 43  38\tNinetales\tFire\t\t505\t73\t76\t75\t81\t10...
# 44  39\tJigglypuff\tNormal\tFairy\t270\t115\t45\t2...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 45  40\tWigglytuff\tNormal\tFairy\t435\t140\t70\t4...
# 46  41\tZubat\tPoison\tFlying\t245\t40\t45\t35\t30...
# 47  42\tGolbat\tPoison\tFlying\t455\t75\t80\t70\t6...
# 48  43\tOddish\tGrass\tPoison\t320\t45\t50\t55\t75...
# 49  44\tGloom\tGrass\tPoison\t395\t60\t65\t70\t85\...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 50  45\tVileplume\tGrass\tPoison\t490\t75\t80\t85\...
# 51  46\tParas\tBug\tGrass\t285\t35\t70\t55\t45\t55...
# 52  47\tParasect\tBug\tGrass\t405\t60\t95\t80\t60\...
# 53  48\tVenonat\tBug\tPoison\t305\t60\t55\t50\t40\...
# 54  49\tVenomoth\tBug\tPoison\t450\t70\t65\t60\t90...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 55  50\tDiglett\tGround\t\t265\t10\t55\t25\t35\t45...
# 56  51\tDugtrio\tGround\t\t405\t35\t80\t50\t50\t70...
# 57  52\tMeowth\tNormal\t\t290\t40\t45\t35\t40\t40\...
# 58  53\tPersian\tNormal\t\t440\t65\t70\t60\t65\t65...
# 59  54\tPsyduck\tWater\t\t320\t50\t52\t48\t65\t50\...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 60  55\tGolduck\tWater\t\t500\t80\t82\t78\t95\t80\...
# 61  56\tMankey\tFighting\t\t305\t40\t80\t35\t35\t4...
# 62  57\tPrimeape\tFighting\t\t455\t65\t105\t60\t60...
# 63  58\tGrowlithe\tFire\t\t350\t55\t70\t45\t70\t50...
# 64  59\tArcanine\tFire\t\t555\t90\t110\t80\t100\t8...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 65  60\tPoliwag\tWater\t\t300\t40\t50\t40\t40\t40\...
# 66  61\tPoliwhirl\tWater\t\t385\t65\t65\t65\t50\t5...
# 67  62\tPoliwrath\tWater\tFighting\t510\t90\t95\t9...
# 68  63\tAbra\tPsychic\t\t310\t25\t20\t15\t105\t55\...
# 69  64\tKadabra\tPsychic\t\t400\t40\t35\t30\t120\t...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 70  65\tAlakazam\tPsychic\t\t500\t55\t50\t45\t135\...
# 71  65\tAlakazamMega Alakazam\tPsychic\t\t590\t55\...
# 72  66\tMachop\tFighting\t\t305\t70\t80\t50\t35\t3...
# 73  67\tMachoke\tFighting\t\t405\t80\t100\t70\t50\...
# 74  68\tMachamp\tFighting\t\t505\t90\t130\t80\t65\...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 75  69\tBellsprout\tGrass\tPoison\t300\t50\t75\t35...
# 76  70\tWeepinbell\tGrass\tPoison\t390\t65\t90\t50...
# 77  71\tVictreebel\tGrass\tPoison\t490\t80\t105\t6...
# 78  72\tTentacool\tWater\tPoison\t335\t40\t40\t35\...
# 79  73\tTentacruel\tWater\tPoison\t515\t80\t70\t65...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 80  74\tGeodude\tRock\tGround\t300\t40\t80\t100\t3...
# 81  75\tGraveler\tRock\tGround\t390\t55\t95\t115\t...
# 82  76\tGolem\tRock\tGround\t495\t80\t120\t130\t55...
# 83  77\tPonyta\tFire\t\t410\t50\t85\t55\t65\t65\t9...
# 84  78\tRapidash\tFire\t\t500\t65\t100\t70\t80\t80...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 85  79\tSlowpoke\tWater\tPsychic\t315\t90\t65\t65\...
# 86  80\tSlowbro\tWater\tPsychic\t490\t95\t75\t110\...
# 87  80\tSlowbroMega Slowbro\tWater\tPsychic\t590\t...
# 88  81\tMagnemite\tElectric\tSteel\t325\t25\t35\t7...
# 89  82\tMagneton\tElectric\tSteel\t465\t50\t60\t95...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 90  83\tFarfetch'd\tNormal\tFlying\t352\t52\t65\t5...
# 91  84\tDoduo\tNormal\tFlying\t310\t35\t85\t45\t35...
# 92  85\tDodrio\tNormal\tFlying\t460\t60\t110\t70\t...
# 93  86\tSeel\tWater\t\t325\t65\t45\t55\t45\t70\t45...
# 94  87\tDewgong\tWater\tIce\t475\t90\t70\t80\t70\t...
#    #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 95  88\tGrimer\tPoison\t\t325\t80\t80\t50\t40\t50\...
# 96  89\tMuk\tPoison\t\t500\t105\t105\t75\t65\t100\...
# 97  90\tShellder\tWater\t\t305\t30\t65\t100\t45\t2...
# 98  91\tCloyster\tWater\tIce\t525\t50\t95\t180\t85...
# 99  92\tGastly\tGhost\tPoison\t310\t30\t35\t30\t10...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 100  93\tHaunter\tGhost\tPoison\t405\t45\t50\t45\t1...
# 101  94\tGengar\tGhost\tPoison\t500\t60\t65\t60\t13...
# 102  94\tGengarMega Gengar\tGhost\tPoison\t600\t60\...
# 103  95\tOnix\tRock\tGround\t385\t35\t45\t160\t30\t...
# 104  96\tDrowzee\tPsychic\t\t328\t60\t48\t45\t43\t9...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 105  97\tHypno\tPsychic\t\t483\t85\t73\t70\t73\t115...
# 106  98\tKrabby\tWater\t\t325\t30\t105\t90\t25\t25\...
# 107  99\tKingler\tWater\t\t475\t55\t130\t115\t50\t5...
# 108  100\tVoltorb\tElectric\t\t330\t40\t30\t50\t55\...
# 109  101\tElectrode\tElectric\t\t480\t60\t50\t70\t8...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 110  102\tExeggcute\tGrass\tPsychic\t325\t60\t40\t8...
# 111  103\tExeggutor\tGrass\tPsychic\t520\t95\t95\t8...
# 112  104\tCubone\tGround\t\t320\t50\t50\t95\t40\t50...
# 113  105\tMarowak\tGround\t\t425\t60\t80\t110\t50\t...
# 114  106\tHitmonlee\tFighting\t\t455\t50\t120\t53\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 115  107\tHitmonchan\tFighting\t\t455\t50\t105\t79\...
# 116  108\tLickitung\tNormal\t\t385\t90\t55\t75\t60\...
# 117  109\tKoffing\tPoison\t\t340\t40\t65\t95\t60\t4...
# 118  110\tWeezing\tPoison\t\t490\t65\t90\t120\t85\t...
# 119  111\tRhyhorn\tGround\tRock\t345\t80\t85\t95\t3...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 120  112\tRhydon\tGround\tRock\t485\t105\t130\t120\...
# 121  113\tChansey\tNormal\t\t450\t250\t5\t5\t35\t10...
# 122  114\tTangela\tGrass\t\t435\t65\t55\t115\t100\t...
# 123  115\tKangaskhan\tNormal\t\t490\t105\t95\t80\t4...
# 124  115\tKangaskhanMega Kangaskhan\tNormal\t\t590\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 125  116\tHorsea\tWater\t\t295\t30\t40\t70\t70\t25\...
# 126  117\tSeadra\tWater\t\t440\t55\t65\t95\t95\t45\...
# 127  118\tGoldeen\tWater\t\t320\t45\t67\t60\t35\t50...
# 128  119\tSeaking\tWater\t\t450\t80\t92\t65\t65\t80...
# 129  120\tStaryu\tWater\t\t340\t30\t45\t55\t70\t55\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 130  121\tStarmie\tWater\tPsychic\t520\t60\t75\t85\...
# 131  122\tMr. Mime\tPsychic\tFairy\t460\t40\t45\t65...
# 132  123\tScyther\tBug\tFlying\t500\t70\t110\t80\t5...
# 133  124\tJynx\tIce\tPsychic\t455\t65\t50\t35\t115\...
# 134  125\tElectabuzz\tElectric\t\t490\t65\t83\t57\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 135  126\tMagmar\tFire\t\t495\t65\t95\t57\t100\t85\...
# 136  127\tPinsir\tBug\t\t500\t65\t125\t100\t55\t70\...
# 137  127\tPinsirMega Pinsir\tBug\tFlying\t600\t65\t...
# 138  128\tTauros\tNormal\t\t490\t75\t100\t95\t40\t7...
# 139  129\tMagikarp\tWater\t\t200\t20\t10\t55\t15\t2...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 140  130\tGyarados\tWater\tFlying\t540\t95\t125\t79...
# 141  130\tGyaradosMega Gyarados\tWater\tDark\t640\t...
# 142  131\tLapras\tWater\tIce\t535\t130\t85\t80\t85\...
# 143  132\tDitto\tNormal\t\t288\t48\t48\t48\t48\t48\...
# 144  133\tEevee\tNormal\t\t325\t55\t55\t50\t45\t65\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 145  134\tVaporeon\tWater\t\t525\t130\t65\t60\t110\...
# 146  135\tJolteon\tElectric\t\t525\t65\t65\t60\t110...
# 147  136\tFlareon\tFire\t\t525\t65\t130\t60\t95\t11...
# 148  137\tPorygon\tNormal\t\t395\t65\t60\t70\t85\t7...
# 149  138\tOmanyte\tRock\tWater\t355\t35\t40\t100\t9...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 150  139\tOmastar\tRock\tWater\t495\t70\t60\t125\t1...
# 151  140\tKabuto\tRock\tWater\t355\t30\t80\t90\t55\...
# 152  141\tKabutops\tRock\tWater\t495\t60\t115\t105\...
# 153  142\tAerodactyl\tRock\tFlying\t515\t80\t105\t6...
# 154  142\tAerodactylMega Aerodactyl\tRock\tFlying\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 155  143\tSnorlax\tNormal\t\t540\t160\t110\t65\t65\...
# 156  144\tArticuno\tIce\tFlying\t580\t90\t85\t100\t...
# 157  145\tZapdos\tElectric\tFlying\t580\t90\t90\t85...
# 158  146\tMoltres\tFire\tFlying\t580\t90\t100\t90\t...
# 159  147\tDratini\tDragon\t\t300\t41\t64\t45\t50\t5...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 160  148\tDragonair\tDragon\t\t420\t61\t84\t65\t70\...
# 161  149\tDragonite\tDragon\tFlying\t600\t91\t134\t...
# 162  150\tMewtwo\tPsychic\t\t680\t106\t110\t90\t154...
# 163  150\tMewtwoMega Mewtwo X\tPsychic\tFighting\t7...
# 164  150\tMewtwoMega Mewtwo Y\tPsychic\t\t780\t106\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 165  151\tMew\tPsychic\t\t600\t100\t100\t100\t100\t...
# 166  152\tChikorita\tGrass\t\t318\t45\t49\t65\t49\t...
# 167  153\tBayleef\tGrass\t\t405\t60\t62\t80\t63\t80...
# 168  154\tMeganium\tGrass\t\t525\t80\t82\t100\t83\t...
# 169  155\tCyndaquil\tFire\t\t309\t39\t52\t43\t60\t5...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 170  156\tQuilava\tFire\t\t405\t58\t64\t58\t80\t65\...
# 171  157\tTyphlosion\tFire\t\t534\t78\t84\t78\t109\...
# 172  158\tTotodile\tWater\t\t314\t50\t65\t64\t44\t4...
# 173  159\tCroconaw\tWater\t\t405\t65\t80\t80\t59\t6...
# 174  160\tFeraligatr\tWater\t\t530\t85\t105\t100\t7...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 175  161\tSentret\tNormal\t\t215\t35\t46\t34\t35\t4...
# 176  162\tFurret\tNormal\t\t415\t85\t76\t64\t45\t55...
# 177  163\tHoothoot\tNormal\tFlying\t262\t60\t30\t30...
# 178  164\tNoctowl\tNormal\tFlying\t442\t100\t50\t50...
# 179  165\tLedyba\tBug\tFlying\t265\t40\t20\t30\t40\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 180  166\tLedian\tBug\tFlying\t390\t55\t35\t50\t55\...
# 181  167\tSpinarak\tBug\tPoison\t250\t40\t60\t40\t4...
# 182  168\tAriados\tBug\tPoison\t390\t70\t90\t70\t60...
# 183  169\tCrobat\tPoison\tFlying\t535\t85\t90\t80\t...
# 184  170\tChinchou\tWater\tElectric\t330\t75\t38\t3...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 185  171\tLanturn\tWater\tElectric\t460\t125\t58\t5...
# 186  172\tPichu\tElectric\t\t205\t20\t40\t15\t35\t3...
# 187  173\tCleffa\tFairy\t\t218\t50\t25\t28\t45\t55\...
# 188  174\tIgglybuff\tNormal\tFairy\t210\t90\t30\t15...
# 189  175\tTogepi\tFairy\t\t245\t35\t20\t65\t40\t65\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 190  176\tTogetic\tFairy\tFlying\t405\t55\t40\t85\t...
# 191  177\tNatu\tPsychic\tFlying\t320\t40\t50\t45\t7...
# 192  178\tXatu\tPsychic\tFlying\t470\t65\t75\t70\t9...
# 193  179\tMareep\tElectric\t\t280\t55\t40\t40\t65\t...
# 194  180\tFlaaffy\tElectric\t\t365\t70\t55\t55\t80\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 195  181\tAmpharos\tElectric\t\t510\t90\t75\t85\t11...
# 196  181\tAmpharosMega Ampharos\tElectric\tDragon\t...
# 197  182\tBellossom\tGrass\t\t490\t75\t80\t95\t90\t...
# 198  183\tMarill\tWater\tFairy\t250\t70\t20\t50\t20...
# 199  184\tAzumarill\tWater\tFairy\t420\t100\t50\t80...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 200  185\tSudowoodo\tRock\t\t410\t70\t100\t115\t30\...
# 201  186\tPolitoed\tWater\t\t500\t90\t75\t75\t90\t1...
# 202  187\tHoppip\tGrass\tFlying\t250\t35\t35\t40\t3...
# 203  188\tSkiploom\tGrass\tFlying\t340\t55\t45\t50\...
# 204  189\tJumpluff\tGrass\tFlying\t460\t75\t55\t70\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 205  190\tAipom\tNormal\t\t360\t55\t70\t55\t40\t55\...
# 206  191\tSunkern\tGrass\t\t180\t30\t30\t30\t30\t30...
# 207  192\tSunflora\tGrass\t\t425\t75\t75\t55\t105\t...
# 208  193\tYanma\tBug\tFlying\t390\t65\t65\t45\t75\t...
# 209  194\tWooper\tWater\tGround\t210\t55\t45\t45\t2...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 210  195\tQuagsire\tWater\tGround\t430\t95\t85\t85\...
# 211  196\tEspeon\tPsychic\t\t525\t65\t65\t60\t130\t...
# 212  197\tUmbreon\tDark\t\t525\t95\t65\t110\t60\t13...
# 213  198\tMurkrow\tDark\tFlying\t405\t60\t85\t42\t8...
# 214  199\tSlowking\tWater\tPsychic\t490\t95\t75\t80...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 215  200\tMisdreavus\tGhost\t\t435\t60\t60\t60\t85\...
# 216  201\tUnown\tPsychic\t\t336\t48\t72\t48\t72\t48...
# 217  202\tWobbuffet\tPsychic\t\t405\t190\t33\t58\t3...
# 218  203\tGirafarig\tNormal\tPsychic\t455\t70\t80\t...
# 219  204\tPineco\tBug\t\t290\t50\t65\t90\t35\t35\t1...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 220  205\tForretress\tBug\tSteel\t465\t75\t90\t140\...
# 221  206\tDunsparce\tNormal\t\t415\t100\t70\t70\t65...
# 222  207\tGligar\tGround\tFlying\t430\t65\t75\t105\...
# 223  208\tSteelix\tSteel\tGround\t510\t75\t85\t200\...
# 224  208\tSteelixMega Steelix\tSteel\tGround\t610\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 225  209\tSnubbull\tFairy\t\t300\t60\t80\t50\t40\t4...
# 226  210\tGranbull\tFairy\t\t450\t90\t120\t75\t60\t...
# 227  211\tQwilfish\tWater\tPoison\t430\t65\t95\t75\...
# 228  212\tScizor\tBug\tSteel\t500\t70\t130\t100\t55...
# 229  212\tScizorMega Scizor\tBug\tSteel\t600\t70\t1...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 230  213\tShuckle\tBug\tRock\t505\t20\t10\t230\t10\...
# 231  214\tHeracross\tBug\tFighting\t500\t80\t125\t7...
# 232  214\tHeracrossMega Heracross\tBug\tFighting\t6...
# 233  215\tSneasel\tDark\tIce\t430\t55\t95\t55\t35\t...
# 234  216\tTeddiursa\tNormal\t\t330\t60\t80\t50\t50\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 235  217\tUrsaring\tNormal\t\t500\t90\t130\t75\t75\...
# 236  218\tSlugma\tFire\t\t250\t40\t40\t40\t70\t40\t...
# 237  219\tMagcargo\tFire\tRock\t410\t50\t50\t120\t8...
# 238  220\tSwinub\tIce\tGround\t250\t50\t50\t40\t30\...
# 239  221\tPiloswine\tIce\tGround\t450\t100\t100\t80...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 240  222\tCorsola\tWater\tRock\t380\t55\t55\t85\t65...
# 241  223\tRemoraid\tWater\t\t300\t35\t65\t35\t65\t3...
# 242  224\tOctillery\tWater\t\t480\t75\t105\t75\t105...
# 243  225\tDelibird\tIce\tFlying\t330\t45\t55\t45\t6...
# 244  226\tMantine\tWater\tFlying\t465\t65\t40\t70\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 245  227\tSkarmory\tSteel\tFlying\t465\t65\t80\t140...
# 246  228\tHoundour\tDark\tFire\t330\t45\t60\t30\t80...
# 247  229\tHoundoom\tDark\tFire\t500\t75\t90\t50\t11...
# 248  229\tHoundoomMega Houndoom\tDark\tFire\t600\t7...
# 249  230\tKingdra\tWater\tDragon\t540\t75\t95\t95\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 250  231\tPhanpy\tGround\t\t330\t90\t60\t60\t40\t40...
# 251  232\tDonphan\tGround\t\t500\t90\t120\t120\t60\...
# 252  233\tPorygon2\tNormal\t\t515\t85\t80\t90\t105\...
# 253  234\tStantler\tNormal\t\t465\t73\t95\t62\t85\t...
# 254  235\tSmeargle\tNormal\t\t250\t55\t20\t35\t20\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 255  236\tTyrogue\tFighting\t\t210\t35\t35\t35\t35\...
# 256  237\tHitmontop\tFighting\t\t455\t50\t95\t95\t3...
# 257  238\tSmoochum\tIce\tPsychic\t305\t45\t30\t15\t...
# 258  239\tElekid\tElectric\t\t360\t45\t63\t37\t65\t...
# 259  240\tMagby\tFire\t\t365\t45\t75\t37\t70\t55\t8...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 260  241\tMiltank\tNormal\t\t490\t95\t80\t105\t40\t...
# 261  242\tBlissey\tNormal\t\t540\t255\t10\t10\t75\t...
# 262  243\tRaikou\tElectric\t\t580\t90\t85\t75\t115\...
# 263  244\tEntei\tFire\t\t580\t115\t115\t85\t90\t75\...
# 264  245\tSuicune\tWater\t\t580\t100\t75\t115\t90\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 265  246\tLarvitar\tRock\tGround\t300\t50\t64\t50\t...
# 266  247\tPupitar\tRock\tGround\t410\t70\t84\t70\t6...
# 267  248\tTyranitar\tRock\tDark\t600\t100\t134\t110...
# 268  248\tTyranitarMega Tyranitar\tRock\tDark\t700\...
# 269  249\tLugia\tPsychic\tFlying\t680\t106\t90\t130...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 270  250\tHo-oh\tFire\tFlying\t680\t106\t130\t90\t1...
# 271  251\tCelebi\tPsychic\tGrass\t600\t100\t100\t10...
# 272  252\tTreecko\tGrass\t\t310\t40\t45\t35\t65\t55...
# 273  253\tGrovyle\tGrass\t\t405\t50\t65\t45\t85\t65...
# 274  254\tSceptile\tGrass\t\t530\t70\t85\t65\t105\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 275  254\tSceptileMega Sceptile\tGrass\tDragon\t630...
# 276  255\tTorchic\tFire\t\t310\t45\t60\t40\t70\t50\...
# 277  256\tCombusken\tFire\tFighting\t405\t60\t85\t6...
# 278  257\tBlaziken\tFire\tFighting\t530\t80\t120\t7...
# 279  257\tBlazikenMega Blaziken\tFire\tFighting\t63...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 280  258\tMudkip\tWater\t\t310\t50\t70\t50\t50\t50\...
# 281  259\tMarshtomp\tWater\tGround\t405\t70\t85\t70...
# 282  260\tSwampert\tWater\tGround\t535\t100\t110\t9...
# 283  260\tSwampertMega Swampert\tWater\tGround\t635...
# 284  261\tPoochyena\tDark\t\t220\t35\t55\t35\t30\t3...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 285  262\tMightyena\tDark\t\t420\t70\t90\t70\t60\t6...
# 286  263\tZigzagoon\tNormal\t\t240\t38\t30\t41\t30\...
# 287  264\tLinoone\tNormal\t\t420\t78\t70\t61\t50\t6...
# 288  265\tWurmple\tBug\t\t195\t45\t45\t35\t20\t30\t...
# 289  266\tSilcoon\tBug\t\t205\t50\t35\t55\t25\t25\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 290  267\tBeautifly\tBug\tFlying\t395\t60\t70\t50\t...
# 291  268\tCascoon\tBug\t\t205\t50\t35\t55\t25\t25\t...
# 292  269\tDustox\tBug\tPoison\t385\t60\t50\t70\t50\...
# 293  270\tLotad\tWater\tGrass\t220\t40\t30\t30\t40\...
# 294  271\tLombre\tWater\tGrass\t340\t60\t50\t50\t60...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 295  272\tLudicolo\tWater\tGrass\t480\t80\t70\t70\t...
# 296  273\tSeedot\tGrass\t\t220\t40\t40\t50\t30\t30\...
# 297  274\tNuzleaf\tGrass\tDark\t340\t70\t70\t40\t60...
# 298  275\tShiftry\tGrass\tDark\t480\t90\t100\t60\t9...
# 299  276\tTaillow\tNormal\tFlying\t270\t40\t55\t30\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 300  277\tSwellow\tNormal\tFlying\t430\t60\t85\t60\...
# 301  278\tWingull\tWater\tFlying\t270\t40\t30\t30\t...
# 302  279\tPelipper\tWater\tFlying\t430\t60\t50\t100...
# 303  280\tRalts\tPsychic\tFairy\t198\t28\t25\t25\t4...
# 304  281\tKirlia\tPsychic\tFairy\t278\t38\t35\t35\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 305  282\tGardevoir\tPsychic\tFairy\t518\t68\t65\t6...
# 306  282\tGardevoirMega Gardevoir\tPsychic\tFairy\t...
# 307  283\tSurskit\tBug\tWater\t269\t40\t30\t32\t50\...
# 308  284\tMasquerain\tBug\tFlying\t414\t70\t60\t62\...
# 309  285\tShroomish\tGrass\t\t295\t60\t40\t60\t40\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 310  286\tBreloom\tGrass\tFighting\t460\t60\t130\t8...
# 311  287\tSlakoth\tNormal\t\t280\t60\t60\t60\t35\t3...
# 312  288\tVigoroth\tNormal\t\t440\t80\t80\t80\t55\t...
# 313  289\tSlaking\tNormal\t\t670\t150\t160\t100\t95...
# 314  290\tNincada\tBug\tGround\t266\t31\t45\t90\t30...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 315  291\tNinjask\tBug\tFlying\t456\t61\t90\t45\t50...
# 316  292\tShedinja\tBug\tGhost\t236\t1\t90\t45\t30\...
# 317  293\tWhismur\tNormal\t\t240\t64\t51\t23\t51\t2...
# 318  294\tLoudred\tNormal\t\t360\t84\t71\t43\t71\t4...
# 319  295\tExploud\tNormal\t\t490\t104\t91\t63\t91\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 320  296\tMakuhita\tFighting\t\t237\t72\t60\t30\t20...
# 321  297\tHariyama\tFighting\t\t474\t144\t120\t60\t...
# 322  298\tAzurill\tNormal\tFairy\t190\t50\t20\t40\t...
# 323  299\tNosepass\tRock\t\t375\t30\t45\t135\t45\t9...
# 324  300\tSkitty\tNormal\t\t260\t50\t45\t45\t35\t35...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 325  301\tDelcatty\tNormal\t\t380\t70\t65\t65\t55\t...
# 326  302\tSableye\tDark\tGhost\t380\t50\t75\t75\t65...
# 327  302\tSableyeMega Sableye\tDark\tGhost\t480\t50...
# 328  303\tMawile\tSteel\tFairy\t380\t50\t85\t85\t55...
# 329  303\tMawileMega Mawile\tSteel\tFairy\t480\t50\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 330  304\tAron\tSteel\tRock\t330\t50\t70\t100\t40\t...
# 331  305\tLairon\tSteel\tRock\t430\t60\t90\t140\t50...
# 332  306\tAggron\tSteel\tRock\t530\t70\t110\t180\t6...
# 333  306\tAggronMega Aggron\tSteel\t\t630\t70\t140\...
# 334  307\tMeditite\tFighting\tPsychic\t280\t30\t40\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 335  308\tMedicham\tFighting\tPsychic\t410\t60\t60\...
# 336  308\tMedichamMega Medicham\tFighting\tPsychic\...
# 337  309\tElectrike\tElectric\t\t295\t40\t45\t40\t6...
# 338  310\tManectric\tElectric\t\t475\t70\t75\t60\t1...
# 339  310\tManectricMega Manectric\tElectric\t\t575\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 340  311\tPlusle\tElectric\t\t405\t60\t50\t40\t85\t...
# 341  312\tMinun\tElectric\t\t405\t60\t40\t50\t75\t8...
# 342  313\tVolbeat\tBug\t\t400\t65\t73\t55\t47\t75\t...
# 343  314\tIllumise\tBug\t\t400\t65\t47\t55\t73\t75\...
# 344  315\tRoselia\tGrass\tPoison\t400\t50\t60\t45\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 345  316\tGulpin\tPoison\t\t302\t70\t43\t53\t43\t53...
# 346  317\tSwalot\tPoison\t\t467\t100\t73\t83\t73\t8...
# 347  318\tCarvanha\tWater\tDark\t305\t45\t90\t20\t6...
# 348  319\tSharpedo\tWater\tDark\t460\t70\t120\t40\t...
# 349  319\tSharpedoMega Sharpedo\tWater\tDark\t560\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 350  320\tWailmer\tWater\t\t400\t130\t70\t35\t70\t3...
# 351  321\tWailord\tWater\t\t500\t170\t90\t45\t90\t4...
# 352  322\tNumel\tFire\tGround\t305\t60\t60\t40\t65\...
# 353  323\tCamerupt\tFire\tGround\t460\t70\t100\t70\...
# 354  323\tCameruptMega Camerupt\tFire\tGround\t560\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 355  324\tTorkoal\tFire\t\t470\t70\t85\t140\t85\t70...
# 356  325\tSpoink\tPsychic\t\t330\t60\t25\t35\t70\t8...
# 357  326\tGrumpig\tPsychic\t\t470\t80\t45\t65\t90\t...
# 358  327\tSpinda\tNormal\t\t360\t60\t60\t60\t60\t60...
# 359  328\tTrapinch\tGround\t\t290\t45\t100\t45\t45\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 360  329\tVibrava\tGround\tDragon\t340\t50\t70\t50\...
# 361  330\tFlygon\tGround\tDragon\t520\t80\t100\t80\...
# 362  331\tCacnea\tGrass\t\t335\t50\t85\t40\t85\t40\...
# 363  332\tCacturne\tGrass\tDark\t475\t70\t115\t60\t...
# 364  333\tSwablu\tNormal\tFlying\t310\t45\t40\t60\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 365  334\tAltaria\tDragon\tFlying\t490\t75\t70\t90\...
# 366  334\tAltariaMega Altaria\tDragon\tFairy\t590\t...
# 367  335\tZangoose\tNormal\t\t458\t73\t115\t60\t60\...
# 368  336\tSeviper\tPoison\t\t458\t73\t100\t60\t100\...
# 369  337\tLunatone\tRock\tPsychic\t440\t70\t55\t65\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 370  338\tSolrock\tRock\tPsychic\t440\t70\t95\t85\t...
# 371  339\tBarboach\tWater\tGround\t288\t50\t48\t43\...
# 372  340\tWhiscash\tWater\tGround\t468\t110\t78\t73...
# 373  341\tCorphish\tWater\t\t308\t43\t80\t65\t50\t3...
# 374  342\tCrawdaunt\tWater\tDark\t468\t63\t120\t85\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 375  343\tBaltoy\tGround\tPsychic\t300\t40\t40\t55\...
# 376  344\tClaydol\tGround\tPsychic\t500\t60\t70\t10...
# 377  345\tLileep\tRock\tGrass\t355\t66\t41\t77\t61\...
# 378  346\tCradily\tRock\tGrass\t495\t86\t81\t97\t81...
# 379  347\tAnorith\tRock\tBug\t355\t45\t95\t50\t40\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 380  348\tArmaldo\tRock\tBug\t495\t75\t125\t100\t70...
# 381  349\tFeebas\tWater\t\t200\t20\t15\t20\t10\t55\...
# 382  350\tMilotic\tWater\t\t540\t95\t60\t79\t100\t1...
# 383  351\tCastform\tNormal\t\t420\t70\t70\t70\t70\t...
# 384  352\tKecleon\tNormal\t\t440\t60\t90\t70\t60\t1...
# ...
# 671  610\tAxew\tDragon\t\t320\t46\t87\t60\t30\t40\t...
# 672  611\tFraxure\tDragon\t\t410\t66\t117\t70\t40\t...
# 673  612\tHaxorus\tDragon\t\t540\t76\t147\t90\t60\t...
# 674  613\tCubchoo\tIce\t\t305\t55\t70\t40\t60\t40\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 675  614\tBeartic\tIce\t\t485\t95\t110\t80\t70\t80\...
# 676  615\tCryogonal\tIce\t\t485\t70\t50\t30\t95\t13...
# 677  616\tShelmet\tBug\t\t305\t50\t40\t85\t40\t65\t...
# 678  617\tAccelgor\tBug\t\t495\t80\t70\t40\t100\t60...
# 679  618\tStunfisk\tGround\tElectric\t471\t109\t66\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 680  619\tMienfoo\tFighting\t\t350\t45\t85\t50\t55\...
# 681  620\tMienshao\tFighting\t\t510\t65\t125\t60\t9...
# 682  621\tDruddigon\tDragon\t\t485\t77\t120\t90\t60...
# 683  622\tGolett\tGround\tGhost\t303\t59\t74\t50\t3...
# 684  623\tGolurk\tGround\tGhost\t483\t89\t124\t80\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 685  624\tPawniard\tDark\tSteel\t340\t45\t85\t70\t4...
# 686  625\tBisharp\tDark\tSteel\t490\t65\t125\t100\t...
# 687  626\tBouffalant\tNormal\t\t490\t95\t110\t95\t4...
# 688  627\tRufflet\tNormal\tFlying\t350\t70\t83\t50\...
# 689  628\tBraviary\tNormal\tFlying\t510\t100\t123\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 690  629\tVullaby\tDark\tFlying\t370\t70\t55\t75\t4...
# 691  630\tMandibuzz\tDark\tFlying\t510\t110\t65\t10...
# 692  631\tHeatmor\tFire\t\t484\t85\t97\t66\t105\t66...
# 693  632\tDurant\tBug\tSteel\t484\t58\t109\t112\t48...
# 694  633\tDeino\tDark\tDragon\t300\t52\t65\t50\t45\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 695  634\tZweilous\tDark\tDragon\t420\t72\t85\t70\t...
# 696  635\tHydreigon\tDark\tDragon\t600\t92\t105\t90...
# 697  636\tLarvesta\tBug\tFire\t360\t55\t85\t55\t50\...
# 698  637\tVolcarona\tBug\tFire\t550\t85\t60\t65\t13...
# 699  638\tCobalion\tSteel\tFighting\t580\t91\t90\t1...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 700  639\tTerrakion\tRock\tFighting\t580\t91\t129\t...
# 701  640\tVirizion\tGrass\tFighting\t580\t91\t90\t7...
# 702  641\tTornadusIncarnate Forme\tFlying\t\t580\t7...
# 703  641\tTornadusTherian Forme\tFlying\t\t580\t79\...
# 704  642\tThundurusIncarnate Forme\tElectric\tFlyin...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 705  642\tThundurusTherian Forme\tElectric\tFlying\...
# 706  643\tReshiram\tDragon\tFire\t680\t100\t120\t10...
# 707  644\tZekrom\tDragon\tElectric\t680\t100\t150\t...
# 708  645\tLandorusIncarnate Forme\tGround\tFlying\t...
# 709  645\tLandorusTherian Forme\tGround\tFlying\t60...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 710  646\tKyurem\tDragon\tIce\t660\t125\t130\t90\t1...
# 711  646\tKyuremBlack Kyurem\tDragon\tIce\t700\t125...
# 712  646\tKyuremWhite Kyurem\tDragon\tIce\t700\t125...
# 713  647\tKeldeoOrdinary Forme\tWater\tFighting\t58...
# 714  647\tKeldeoResolute Forme\tWater\tFighting\t58...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 715  648\tMeloettaAria Forme\tNormal\tPsychic\t600\...
# 716  648\tMeloettaPirouette Forme\tNormal\tFighting...
# 717  649\tGenesect\tBug\tSteel\t600\t71\t120\t95\t1...
# 718  650\tChespin\tGrass\t\t313\t56\t61\t65\t48\t45...
# 719  651\tQuilladin\tGrass\t\t405\t61\t78\t95\t56\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 720  652\tChesnaught\tGrass\tFighting\t530\t88\t107...
# 721  653\tFennekin\tFire\t\t307\t40\t45\t40\t62\t60...
# 722  654\tBraixen\tFire\t\t409\t59\t59\t58\t90\t70\...
# 723  655\tDelphox\tFire\tPsychic\t534\t75\t69\t72\t...
# 724  656\tFroakie\tWater\t\t314\t41\t56\t40\t62\t44...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 725  657\tFrogadier\tWater\t\t405\t54\t63\t52\t83\t...
# 726  658\tGreninja\tWater\tDark\t530\t72\t95\t67\t1...
# 727  659\tBunnelby\tNormal\t\t237\t38\t36\t38\t32\t...
# 728  660\tDiggersby\tNormal\tGround\t423\t85\t56\t7...
# 729  661\tFletchling\tNormal\tFlying\t278\t45\t50\t...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 730  662\tFletchinder\tFire\tFlying\t382\t62\t73\t5...
# 731  663\tTalonflame\tFire\tFlying\t499\t78\t81\t71...
# 732  664\tScatterbug\tBug\t\t200\t38\t35\t40\t27\t2...
# 733  665\tSpewpa\tBug\t\t213\t45\t22\t60\t27\t30\t2...
# 734  666\tVivillon\tBug\tFlying\t411\t80\t52\t50\t9...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 735  667\tLitleo\tFire\tNormal\t369\t62\t50\t58\t73...
# 736  668\tPyroar\tFire\tNormal\t507\t86\t68\t72\t10...
# 737  669\tFlabébé\tFairy\t\t303\t44\t38\t39\t61\t79...
# 738  670\tFloette\tFairy\t\t371\t54\t45\t47\t75\t98...
# 739  671\tFlorges\tFairy\t\t552\t78\t65\t68\t112\t1...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 740  672\tSkiddo\tGrass\t\t350\t66\t65\t48\t62\t57\...
# 741  673\tGogoat\tGrass\t\t531\t123\t100\t62\t97\t8...
# 742  674\tPancham\tFighting\t\t348\t67\t82\t62\t46\...
# 743  675\tPangoro\tFighting\tDark\t495\t95\t124\t78...
# 744  676\tFurfrou\tNormal\t\t472\t75\t80\t60\t65\t9...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 745  677\tEspurr\tPsychic\t\t355\t62\t48\t54\t63\t6...
# 746  678\tMeowsticMale\tPsychic\t\t466\t74\t48\t76\...
# 747  678\tMeowsticFemale\tPsychic\t\t466\t74\t48\t7...
# 748  679\tHonedge\tSteel\tGhost\t325\t45\t80\t100\t...
# 749  680\tDoublade\tSteel\tGhost\t448\t59\t110\t150...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 750  681\tAegislashBlade Forme\tSteel\tGhost\t520\t...
# 751  681\tAegislashShield Forme\tSteel\tGhost\t520\...
# 752  682\tSpritzee\tFairy\t\t341\t78\t52\t60\t63\t6...
# 753  683\tAromatisse\tFairy\t\t462\t101\t72\t72\t99...
# 754  684\tSwirlix\tFairy\t\t341\t62\t48\t66\t59\t57...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 755  685\tSlurpuff\tFairy\t\t480\t82\t80\t86\t85\t7...
# 756  686\tInkay\tDark\tPsychic\t288\t53\t54\t53\t37...
# 757  687\tMalamar\tDark\tPsychic\t482\t86\t92\t88\t...
# 758  688\tBinacle\tRock\tWater\t306\t42\t52\t67\t39...
# 759  689\tBarbaracle\tRock\tWater\t500\t72\t105\t11...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 760  690\tSkrelp\tPoison\tWater\t320\t50\t60\t60\t6...
# 761  691\tDragalge\tPoison\tDragon\t494\t65\t75\t90...
# 762  692\tClauncher\tWater\t\t330\t50\t53\t62\t58\t...
# 763  693\tClawitzer\tWater\t\t500\t71\t73\t88\t120\...
# 764  694\tHelioptile\tElectric\tNormal\t289\t44\t38...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 765  695\tHeliolisk\tElectric\tNormal\t481\t62\t55\...
# 766  696\tTyrunt\tRock\tDragon\t362\t58\t89\t77\t45...
# 767  697\tTyrantrum\tRock\tDragon\t521\t82\t121\t11...
# 768  698\tAmaura\tRock\tIce\t362\t77\t59\t50\t67\t6...
# 769  699\tAurorus\tRock\tIce\t521\t123\t77\t72\t99\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 770  700\tSylveon\tFairy\t\t525\t95\t65\t65\t110\t1...
# 771  701\tHawlucha\tFighting\tFlying\t500\t78\t92\t...
# 772  702\tDedenne\tElectric\tFairy\t431\t67\t58\t57...
# 773  703\tCarbink\tRock\tFairy\t500\t50\t50\t150\t5...
# 774  704\tGoomy\tDragon\t\t300\t45\t50\t35\t55\t75\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 775  705\tSliggoo\tDragon\t\t452\t68\t75\t53\t83\t1...
# 776  706\tGoodra\tDragon\t\t600\t90\t100\t70\t110\t...
# 777  707\tKlefki\tSteel\tFairy\t470\t57\t80\t91\t80...
# 778  708\tPhantump\tGhost\tGrass\t309\t43\t70\t48\t...
# 779  709\tTrevenant\tGhost\tGrass\t474\t85\t110\t76...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 780  710\tPumpkabooAverage Size\tGhost\tGrass\t335\...
# 781  710\tPumpkabooSmall Size\tGhost\tGrass\t335\t4...
# 782  710\tPumpkabooLarge Size\tGhost\tGrass\t335\t5...
# 783  710\tPumpkabooSuper Size\tGhost\tGrass\t335\t5...
# 784  711\tGourgeistAverage Size\tGhost\tGrass\t494\...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 785  711\tGourgeistSmall Size\tGhost\tGrass\t494\t5...
# 786  711\tGourgeistLarge Size\tGhost\tGrass\t494\t7...
# 787  711\tGourgeistSuper Size\tGhost\tGrass\t494\t8...
# 788  712\tBergmite\tIce\t\t304\t55\t69\t85\t32\t35\...
# 789  713\tAvalugg\tIce\t\t514\t95\t117\t184\t44\t46...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 790  714\tNoibat\tFlying\tDragon\t245\t40\t30\t35\t...
# 791  715\tNoivern\tFlying\tDragon\t535\t85\t70\t80\...
# 792  716\tXerneas\tFairy\t\t680\t126\t131\t95\t131\...
# 793  717\tYveltal\tDark\tFlying\t680\t126\t131\t95\...
# 794  718\tZygarde50% Forme\tDragon\tGround\t600\t10...
#     #\tName\tType 1\tType 2\tTotal\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 795  719\tDiancie\tRock\tFairy\t600\t50\t100\t150\t...
# 796  719\tDiancieMega Diancie\tRock\tFairy\t700\t50...
# 797  720\tHoopaHoopa Confined\tPsychic\tGhost\t600\...
# 798  720\tHoopaHoopa Unbound\tPsychic\tDark\t680\t8...
# 799  721\tVolcanion\tFire\tWater\t600\t80\t110\t120...
